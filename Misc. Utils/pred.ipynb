# %%
from ultralytics import YOLO

# %%
model = YOLO("E:/SOI_SC/runs/detect/train19 nb2/weights/best.pt")

# %%
# model(source="E:/SOI_SC/Data/images/val/7.947675057711304,9.319555897548636,-60.906892382103955,-59.53501154226666.png", show=True, save=True, show_labels=False, line_width=1)

# %%
# model(source="E:/SOI_SC/Data/images/val/-19.48994173903485,-18.11806089919752,57.074859843904555,58.44674068374186.png", show=True, save=True, show_labels=False, line_width=1)

# %%
#best

# model.val(data="config.yaml", split='val', save=True, conf=0.20, plots=True)

# %%
model.val(data="config.yaml", split='val', save=True, conf=0.22, plots=True)
# Out:
# Ultralytics 8.3.152  Python-3.11.7 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# YOLOv8n summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.30.2 ms, read: 7.46.6 MB/s, size: 59.1 KB)
# val: Scanning E:\SOI_SC\Data\labels\val.cache... 3712 images, 48 backgrounds, 0 corrupt: 100%|██████████| 3740/3740 [00:00<?, ?it/s]
# val: E:\SOI_SC\Data\images\val\Lunar_A-13-15_jpg.rf.38ef2ac1d37ccf9f2f4846ee6acbc964.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-15_jpg.rf.55d8b7aab578aee27a3bd6c92a9f6f0f.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-32_jpg.rf.b0a6c910ec04ef3997cc513f4c020d83.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-21_jpg.rf.6a66c495e5afc19b3ea5d61471ee1757.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-30_jpg.rf.0660e8cdeaf99f3d42a1c85dc66982b6.jpg: 1 duplicate labels removed
# ...

# %%
model.val(data="config.yaml", split='val', save=True, conf=0.23, plots=True)
# Out:
# Ultralytics 8.3.152  Python-3.11.7 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# val: Fast image access  (ping: 0.00.0 ms, read: 367.9357.4 MB/s, size: 63.1 KB)
# val: Scanning E:\SOI_SC\Data\labels\val.cache... 3712 images, 48 backgrounds, 0 corrupt: 100%|██████████| 3740/3740 [00:00<?, ?it/s]
# val: E:\SOI_SC\Data\images\val\Lunar_A-13-15_jpg.rf.38ef2ac1d37ccf9f2f4846ee6acbc964.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-15_jpg.rf.55d8b7aab578aee27a3bd6c92a9f6f0f.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-32_jpg.rf.b0a6c910ec04ef3997cc513f4c020d83.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-21_jpg.rf.6a66c495e5afc19b3ea5d61471ee1757.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-30_jpg.rf.0660e8cdeaf99f3d42a1c85dc66982b6.jpg: 1 duplicate labels removed
# ...

# %%
# model.val(data="config.yaml", split='val', save=True, conf=0.18, plots=True)
# Out:
# Ultralytics 8.3.152  Python-3.11.7 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# val: Fast image access  (ping: 0.00.0 ms, read: 803.9534.3 MB/s, size: 66.6 KB)
# val: Scanning E:\SOI_SC\Data\labels\val.cache... 3712 images, 48 backgrounds, 0 corrupt: 100%|██████████| 3740/3740 [00:00<?, ?it/s]
# val: E:\SOI_SC\Data\images\val\Lunar_A-13-15_jpg.rf.38ef2ac1d37ccf9f2f4846ee6acbc964.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-15_jpg.rf.55d8b7aab578aee27a3bd6c92a9f6f0f.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-32_jpg.rf.b0a6c910ec04ef3997cc513f4c020d83.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-21_jpg.rf.6a66c495e5afc19b3ea5d61471ee1757.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-30_jpg.rf.0660e8cdeaf99f3d42a1c85dc66982b6.jpg: 1 duplicate labels removed
# ...

# %%
# model.val(data="config.yaml", split='val', save=True, conf=0.21, plots=True)
# Out:
# Ultralytics 8.3.152  Python-3.11.7 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# val: Fast image access  (ping: 0.00.0 ms, read: 387.1197.1 MB/s, size: 36.4 KB)
# val: Scanning E:\SOI_SC\Data\labels\val.cache... 3712 images, 48 backgrounds, 0 corrupt: 100%|██████████| 3740/3740 [00:00<?, ?it/s]
# val: E:\SOI_SC\Data\images\val\Lunar_A-13-15_jpg.rf.38ef2ac1d37ccf9f2f4846ee6acbc964.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-15_jpg.rf.55d8b7aab578aee27a3bd6c92a9f6f0f.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-32_jpg.rf.b0a6c910ec04ef3997cc513f4c020d83.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-21_jpg.rf.6a66c495e5afc19b3ea5d61471ee1757.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-30_jpg.rf.0660e8cdeaf99f3d42a1c85dc66982b6.jpg: 1 duplicate labels removed
# ...

# %%
# model.val(data="config.yaml", split='val', save=True, conf=0.24, plots=True)
# Out:
# Ultralytics 8.3.152  Python-3.11.7 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# val: Fast image access  (ping: 0.00.0 ms, read: 886.7688.5 MB/s, size: 60.9 KB)
# val: Scanning E:\SOI_SC\Data\labels\val.cache... 3712 images, 48 backgrounds, 0 corrupt: 100%|██████████| 3740/3740 [00:00<?, ?it/s]
# val: E:\SOI_SC\Data\images\val\Lunar_A-13-15_jpg.rf.38ef2ac1d37ccf9f2f4846ee6acbc964.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-15_jpg.rf.55d8b7aab578aee27a3bd6c92a9f6f0f.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-32_jpg.rf.b0a6c910ec04ef3997cc513f4c020d83.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-21_jpg.rf.6a66c495e5afc19b3ea5d61471ee1757.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-30_jpg.rf.0660e8cdeaf99f3d42a1c85dc66982b6.jpg: 1 duplicate labels removed
# ...

# %%
# model.val(data="config.yaml", split='val', save=True, conf=0.27, plots=True)
# Out:
# Ultralytics 8.3.152  Python-3.11.7 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# val: Fast image access  (ping: 0.10.1 ms, read: 374.5127.4 MB/s, size: 51.4 KB)
# val: Scanning E:\SOI_SC\Data\labels\val.cache... 3712 images, 48 backgrounds, 0 corrupt: 100%|██████████| 3740/3740 [00:00<?, ?it/s]
# val: E:\SOI_SC\Data\images\val\Lunar_A-13-15_jpg.rf.38ef2ac1d37ccf9f2f4846ee6acbc964.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-15_jpg.rf.55d8b7aab578aee27a3bd6c92a9f6f0f.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-17-32_jpg.rf.b0a6c910ec04ef3997cc513f4c020d83.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-21_jpg.rf.6a66c495e5afc19b3ea5d61471ee1757.jpg: 1 duplicate labels removed
# val: E:\SOI_SC\Data\images\val\Lunar_A-6-30_jpg.rf.0660e8cdeaf99f3d42a1c85dc66982b6.jpg: 1 duplicate labels removed
# ...
