# %%
from ultralytics import YOLO
import os
from pathlib import Path
import cv2

# %%
model = YOLO("E:/SOI_SC/runs/detect/train19 nb2/weights/best.pt")

# %%
# model(source="C:/Users/HP5CD/Desktop/train/-0.28360998131250864,1.0882708585247933,-3.287897108937001,-1.916016269099713.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/train/-0.28360998131250864,1.0882708585247933,-10.147301308123556,-8.775420468286237.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/train/-0.28360998131250864,1.0882708585247933,3.571507090249538,4.94338793008684.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/train/-0.28360998131250864,1.0882708585247933,6.315268769924142,7.687149609761457.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/train/-0.28360998131250864,1.0882708585247933,7.687149609761457,9.05903044959876.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/train/-0.28360998131250864,1.0882708585247933,10.430911289436077,11.802792129273378.png", show=True, save=True, show_labels=False, line_width=1)



# model(source="C:/Users/HP5CD/Desktop/valid/-0.28360998131250864,1.0882708585247933,-36.213037265032405,-34.841156425195095.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/valid/-0.28360998131250864,1.0882708585247933,13.17467296911068,14.546553808948.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/valid/-0.28360998131250864,1.0882708585247933,28.26536220732108,29.637243047158382.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/valid/-0.28360998131250864,1.0882708585247933,65.3061448829284,66.67802572276571.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/valid/1.0882708585247933,2.460151698362067,-14.262943827635459,-12.89106298779817.png", show=True, save=True, show_labels=False, line_width=1)

# model(source="C:/Users/HP5CD/Desktop/valid/1.0882708585247933,2.460151698362067,3.571507090249538,4.94338793008684.png", show=True, save=True, show_labels=False, line_width=1)

# %%
image_extensions = ['.jpg', '.jpeg', '.png']
image_files = [f for f in Path('comp').glob("*") if f.suffix.lower() in image_extensions]

# %%
for img in image_files:
    model(source=img, save=True, show_labels=False, line_width=1, conf=0.23)
# Out:
# image 1/1 e:\SOI_SC\comp\-0.28360998131250864,1.0882708585247933,-10.147301308123556,-8.775420468286237.png: 640x640 229 craters, 88.4ms
# Speed: 3.2ms preprocess, 88.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict3
#
# image 1/1 e:\SOI_SC\comp\-0.28360998131250864,1.0882708585247933,-11.519182147960857,-10.147301308123556.png: 640x640 173 craters, 82.7ms
# Speed: 2.8ms preprocess, 82.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict3
#
# image 1/1 e:\SOI_SC\comp\-0.28360998131250864,1.0882708585247933,-14.262943827635459,-12.89106298779817.png: 640x640 181 craters, 80.0ms
# Speed: 1.7ms preprocess, 80.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict3
#
# image 1/1 e:\SOI_SC\comp\-0.28360998131250864,1.0882708585247933,-18.378586347147394,-17.006705507310105.png: 640x640 180 craters, 81.7ms
# ...
